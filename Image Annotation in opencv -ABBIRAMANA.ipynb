# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("Downloads/pro1.csv")

# %%
a.head()
# Out:
#   label_name  bbox_x  bbox_y  bbox_width  bbox_height   image_name  \
# 0     humans     144      11          52          134  OIP (1).jpg
# 1     humans     208      11          37          125  OIP (1).jpg
# 2     humans     257       4          44           90  OIP (1).jpg
# 3      lions      23      84         137          129  OIP (1).jpg
# 4      lions     217      71          79          146  OIP (1).jpg
#
#    image_width  image_height
# 0          474           296
# 1          474           296
# 2          474           296
# 3          474           296
# 4          474           296

# %%
# !pip install opencv-python

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    6 non-null      object
#  1   bbox_x        6 non-null      int64
#  2   bbox_y        6 non-null      int64
#  3   bbox_width    6 non-null      int64
#  4   bbox_height   6 non-null      int64
#  5   image_name    6 non-null      object
#  6   image_width   6 non-null      int64
#  7   image_height  6 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 512.0+ bytes

# %%
a.sum()
# Out:
# label_name                      humanshumanshumanslionslionslions
# bbox_x                                                       1157
# bbox_y                                                        260
# bbox_width                                                    499
# bbox_height                                                   832
# image_name      OIP (1).jpgOIP (1).jpgOIP (1).jpgOIP (1).jpgOI...
# image_width                                                  2844
# image_height                                                 1776
# dtype: object

# %%
a.isnull().sum()
# Out:
# label_name      0
# bbox_x          0
# bbox_y          0
# bbox_width      0
# bbox_height     0
# image_name      0
# image_width     0
# image_height    0
# dtype: int64

# %%
sns.pairplot(a)

# %%
d=sns.boxplot(data=a)

# %%
sns.jointplot(data=a)

# %%
sns.pointplot(data=a)
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(data=a)

# %%
sns.lineplot(data=a)
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=a)

# %%
import matplotlib.image as img

# %%
from sklearn import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11224/4179059895.py in <module>
# ----> 1 from sklearn import train_test_split
#
# ImportError: cannot import name 'train_test_split' from 'sklearn' (C:\Users\STUDENT\anaconda3\lib\site-packages\sklearn\__init__.py)

# %%
testimg=img.imread("Pictures/OIP (1).jpg")
plt.imshow(testimg)

# %%
import cv2

# %%
Start_point=(4,4)
End_pont=(220,220)
colour=(250,0,0)
thickness=9

# %%
mg=cv2.rectangle(testimg,Start_point,End_pont,colour,thickness)

# %%
mg
# Out:
# array([[[111, 115,  80],
#         [250,   0,   0],
#         [250,   0,   0],
#         ...,
#         [101, 120,  75],
#         [105, 124,  79],
#         [105, 124,  79]],
#
#        [[250,   0,   0],
#         [250,   0,   0],
#         [250,   0,   0],
#         ...,
#         [100, 119,  74],
#         [103, 122,  77],
#         [103, 122,  77]],
#
#        [[250,   0,   0],
#         [250,   0,   0],
#         [250,   0,   0],
#         ...,
#         [ 98, 117,  72],
#         [100, 119,  74],
#         [100, 119,  74]],
#
#        ...,
#
#        [[ 90, 107,  55],
#         [ 83,  99,  50],
#         [ 69,  87,  39],
#         ...,
#         [ 26,  21,   2],
#         [ 21,  14,   0],
#         [ 44,  34,  22]],
#
#        [[ 98, 114,  65],
#         [ 76,  94,  46],
#         [ 68,  85,  40],
#         ...,
#         [ 29,  24,   5],
#         [ 43,  35,  22],
#         [ 73,  65,  54]],
#
#        [[106, 124,  76],
#         [ 73,  90,  45],
#         [ 68,  87,  42],
# ...

# %%
cv2.imshow("free",testimg)
cv2.waitKey(0)
# Out:
# -1
